# %%
import re
import time
from typing import Iterator
import requests
import lxml
from bs4 import BeautifulSoup
from pymongo import MongoClient

# %%
#クローラー
def main():
    """
    クローラーのメインの処理。
    """
    client = MongoClient('localhost', 27017)  # ローカルホストのMongoDBに接続する。
    collection = client.scraping.coe  # scrapingデータベースのcoeコレクションを得る。
    # データを一意に識別するキーを格納するkeyフィールドにユニークなインデックスを作成する。
    collection.create_index('key', unique=False)
    
    headers = requests.utils.default_headers()
    headers['User-Agent'] = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.2 Safari/605.1.15'

    session = requests.Session()
    response = session.get('https://allianceforcoffeeexcellence.org/competition-auction-results/')  # 一覧ページを取得する。
    urls = scrape_list_page(response)  # 詳細ページのURL一覧を得る。
    for url in urls:
        key = extract_key(url)  # URLからキーを取得する。
        coe = collection.find_one({'key': key})  # MongoDBからkeyに該当するデータを探す。
        if not coe:  # MongoDBに存在しない場合だけ、詳細ページをクロールする。
            time.sleep(3)
            response = session.get(url)  # 詳細ページを取得する。
            try:
                results = scrape_detail_page(response)
                for result in results:
                    result = {k.replace('.',''): v for k, v in result.items() if type(k) != int}
                    collection.insert_one(result)  # 表の情報をMongoDBのcoeコレクションに保存する。
            #No tableの場合
            except ValueError:
                continue        

#         print(data)  # 表の情報を表示する。

#スクレイピング
def scrape_list_page(response: requests.Response) -> Iterator[str]:
    """
    一覧ページのResponseから詳細ページのURLを抜き出すジェネレーター関数。
    """
    html = lxml.html.fromstring(response.text)
    html.make_links_absolute(response.url)

    for a in html.cssselect('#menu-coe-country-programs-menu a[href^="https://"]'):
        #:not(#menu-item-65034)
        url = a.get('href')
        yield url


def scrape_detail_page(response: requests.Response) -> dict:
    """
    詳細ページのResponseから表の情報をdictで取得する。
    """
#     html = lxml.html.fromstring(response.text)
    tables = pd.read_html(response.content)
    data = None
    #列名修正ver
    if 'rank' in list(table[0].iloc[0].str.lower().values):
        tables[0].columns = tables[0].iloc[0]
        tables[0].drop(index=0, inplace=True)
        data = tables[0]
        for x in range(1, len(tables)):
            if len(tables[0])-3 <= len(tables[x]) <= len(tables[0])+3:
                tables[x].columns = tables[x].iloc[0]
                tables[x].drop(index=0, inplace=True)
                data = pd.concat([data, tables[x]], axis=1, sort=False)
        #オークションに関するカップ情報の辞書を作成
        data = data.to_dict(orient='records')
        #key, urlの追加
        for i in range(len(data)):
            data[i]['key'] = extract_key(response.url)
            data[i]['url'] = response.url
        return data  # dictを返す。
    
    else:
        #オークション情報の整形
        data = tables[0]
        #目的となるtableのみdataに追加
        for x in range(1, len(tables)):
            if len(tables[0])-1 <= len(tables[x]) <= len(tables[0])+1:
                data = pd.concat([data, tables[x]], axis=1, sort=False)
        #オークションに関するカップ情報の辞書を作成
        data = data.to_dict(orient='records')
        #key, urlの追加
        for i in range(len(data)):
            data[i]['key'] = extract_key(response.url)
            data[i]['url'] = response.url
        return data  # dictを返す。
    

def extract_key(url: str) -> str:
    """
    URLからキー（URLの末尾のISBN）を抜き出す。
    """
    m = re.search(r'/([^/]+)/$', url)  # 最後の/から文字列末尾までを正規表現で取得。
    return m.group(1)

if __name__ == '__main__':
    main()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:81: UserWarning: DataFrame columns are not unique, some columns will be omitted.

# %%
#動作確認
url = requests.get('https://allianceforcoffeeexcellence.org/brazil-2019/')
# url = requests.get('https://allianceforcoffeeexcellence.org/bolivia-2009/')
table = pd.read_html(url.content)#多重リスト
if 'rank' in list(table[0].iloc[0].str.lower().values):
    table[0].columns = table[0].iloc[0]
    table[0].drop(index=0, inplace=True)
    data = table[0]
    for x in range(1, len(table)):
        if len(table[0])-2 <= len(table[x]) <= len(table[0])+2:
            table[x].columns = table[x].iloc[0]
            table[x].drop(index=0, inplace=True)
            data = pd.concat([data, table[x]], axis=1, sort=False)
    data = data.to_dict(orient='records')
else:
    data = table[0]
    for x in range(1, len(table)):
        if len(table[0])-2 <= len(table[x]) <= len(table[0])+2:
            data = pd.concat([data, table[x]], axis=1, sort=False)
    data = data.to_dict(orient='records')
data
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   del sys.path[0]
# [{'RANK': '1a',
#   'WEIGHT (kg)': '180',
#   'FARM': 'Fazenda Paie Filho',
#   'FARMER': 'André Luis Aguila Ribeiro',
#   'REGION': 'Sul de Minas',
#   'SCORE': '92.23',
#   'VARIETY': 'Yellow Catuaí',
#   'PROCESS': 'Natural',
#   'ROLE': 'Head Judge',
#   'NAME': 'Eduardo Ambrocio',
#   'COMPANY': 'Eduardo Ambrocio',
#   'COUNTRY': nan,
#   'Rank': '1a',
#   'Farm': 'Fazenda Paie Filho',
#   'Weight (lbs.)': '396.84',
#   'High Bid': '$60.10/lb',
#   'Total Value': '$23,850.08',
#   'Company Name': 'Maruyama Coffee, Goodboybob Coffee, Harrods',
#   'Commissions': '$5,645.05'},
#  {'RANK': '1b',
#   'WEIGHT (kg)': '180',
#   'FARM': 'Fazenda Paie Filho',
#   'FARMER': 'André Luis Aguila Ribeiro',
#   'REGION': 'Sul de Minas',
#   'SCORE': '92.23',
#   'VARIETY': 'Yellow Catuaí',
#   'PROCESS': 'Natural',
#   'ROLE': 'ACE Rep',
#   'NAME': 'Darrin Daniel',
#   'COMPANY': 'Darrin Daniel',
#   'COUNTRY': nan,
#   'Rank': '1b',
#   'Farm': 'Fazenda Paie Filho',
#   'Weight (lbs.)': '396.84',
#   'High Bid': '$50.80/lb',
#   'Total Value': '$20,159.47',
#   'Company Name': 'TAKAMURA COFFEE ROASTERS',
#   'Commissions': '$4,722.40'},
#  {'RANK': '2a',
#   'WEIGHT (kg)': '150',
#   'FARM': 'Fazenda Primavera',
#   'FARMER': 'Leonardo Montesanto Tavares',
#   'REGION': 'Chapada de Minas',
#   'SCORE': '92.15',
#   'VARIETY': 'Gesha',
#   'PROCESS': 'Natural Anaerobic',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Andrew Barnett',
#   'COMPANY': 'Linea',
#   'COUNTRY': 'United States (US)',
#   'Rank': '2a',
#   'Farm': 'Fazenda Primavera',
#   'Weight (lbs.)': '330.7',
#   'High Bid': '$30.50/lb',
#   'Total Value': '$10,086.35',
#   'Company Name': 'SAZA COFFEE, Maruyama Coffee, and\xa0PROUD MARY COFFEE',
#   'Commissions': '$2,257.03'},
#  {'RANK': '2b',
#   'WEIGHT (kg)': '150',
#   'FARM': 'Fazenda Primavera',
#   'FARMER': 'Leonardo Montesanto Tavares',
#   'REGION': 'Chapada de Minas',
#   'SCORE': '92.15',
#   'VARIETY': 'Gesha',
#   'PROCESS': 'Natural Anaerobic',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Beom Kyu Heo',
#   'COMPANY': 'Bean Krush Coffee Company (Waveon Coffee)',
#   'COUNTRY': 'South Korea',
#   'Rank': '2b',
#   'Farm': 'Fazenda Primavera',
#   'Weight (lbs.)': '330.7',
#   'High Bid': '$25.10/lb',
#   'Total Value': '$8,300.57',
#   'Company Name': 'Time’s Club, Coffee Libre, Proud Mary, Coffee Me Up',
#   'Commissions': '$1,810.58'},
#  {'RANK': '3a',
#   'WEIGHT (kg)': '180',
#   'FARM': 'Sítio São Sebastião',
#   'FARMER': 'Merce Jordan Araújo Silva',
#   'REGION': 'Chapada Diamantina',
#   'SCORE': '91.84',
#   'VARIETY': 'Red Catuaí',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Brian Huh',
#   'COMPANY': 'Ally Coffee',
#   'COUNTRY': 'United States (US)',
#   'Rank': '3a',
#   'Farm': 'Sítio São Sebastião',
#   'Weight (lbs.)': '396.84',
#   'High Bid': '$12.90/lb',
#   'Total Value': '$5,119.24',
#   'Company Name': 'Wataru for Nozy Coffee',
#   'Commissions': '$962.34'},
#  {'RANK': '3b',
#   'WEIGHT (kg)': '180',
#   'FARM': 'Sítio São Sebastião',
#   'FARMER': 'Merce Jordan Araújo Silva',
#   'REGION': 'Chapada Diamantina',
#   'SCORE': '91.84',
#   'VARIETY': 'Red Catuaí',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Hans Zevenhek',
#   'COMPANY': 'Daarnhouwer',
#   'COUNTRY': 'Netherlands',
#   'Rank': '3b',
#   'Farm': 'Sítio São Sebastião',
#   'Weight (lbs.)': '396.84',
#   'High Bid': '$13.00/lb',
#   'Total Value': '$5,158.92',
#   'Company Name': 'Kyokuto Fadie Corporation',
#   'Commissions': '$972.26'},
#  {'RANK': '4',
#   'WEIGHT (kg)': '300',
#   'FARM': 'Santuário Sul',
#   'FARMER': 'Santuário Sul',
#   'REGION': 'Mantiqueira de Minas',
#   'SCORE': '90.61',
#   'VARIETY': 'Gesha',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Hidetaka Hayashi',
#   'COMPANY': 'Hayashi Coffee Institute',
#   'COUNTRY': 'Japan',
#   'Rank': '4',
#   'Farm': 'Santuário Sul',
#   'Weight (lbs.)': '661.4',
#   'High Bid': '$20.30/lb',
#   'Total Value': '$13,426.42',
#   'Company Name': 'Maruyama Coffee, SAZA COFFEE, Orsir Coffee(Taiwan)',
#   'Commissions': '$2,827.49'},
#  {'RANK': '5',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Jaguara',
#   'FARMER': 'André Luiz Alvarenga Garcia',
#   'REGION': 'Campo das Vertentes',
#   'SCORE': '90.47',
#   'VARIETY': 'Yellow Catuaí',
#   'PROCESS': 'Natural Anaerobic',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Hirotaka Akimoto',
#   'COMPANY': 'Kyokuto Fadie Corporation',
#   'COUNTRY': 'Japan',
#   'Rank': '5',
#   'Farm': 'Fazenda Jaguara',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$15.30/lb',
#   'Total Value': '$12,143.30',
#   'Company Name': 'Coffee Montage, 304 coffee roasters, Coffee Place, EL CAFE COFFEE ROASTERS, FEBRUARY ROASTERS, Jeju Be Brave',
#   'Commissions': '$2,400.88'},
#  {'RANK': '6',
#   'WEIGHT (kg)': '300',
#   'FARM': 'Sítio d’Água Limpa',
#   'FARMER': 'Marianna Carneiro de Carvalho Junqueira',
#   'REGION': 'Sul de Minas',
#   'SCORE': '89.70',
#   'VARIETY': 'Red Catucaí',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Joe Hsu',
#   'COMPANY': 'Orsir Coffee',
#   'COUNTRY': 'Taiwan',
#   'Rank': '6',
#   'Farm': 'Sítio d’Água Limpa',
#   'Weight (lbs.)': '661.4',
#   'High Bid': '$10.51/lb',
#   'Total Value': '$6,951.31',
#   'Company Name': 'Time’s Club &\xa0PROUD MARY COFFEE',
#   'Commissions': '$1,208.71'},
#  {'RANK': '7',
#   'WEIGHT (kg)': '600',
#   'FARM': 'Fazenda Gerais',
#   'FARMER': 'João Roberto Santana',
#   'REGION': 'Chapada Diamantina',
#   'SCORE': '89.58',
#   'VARIETY': 'Catuaí 144',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Jordan Dabov',
#   'COMPANY': 'Mira Mar 08 Ltd',
#   'COUNTRY': 'Bulgaria',
#   'Rank': '7',
#   'Farm': 'Fazenda Gerais',
#   'Weight (lbs.)': '1322.8',
#   'High Bid': '$8.40/lb',
#   'Total Value': '$11,111.52',
#   'Company Name': 'Terarosa (Haksan Co. Ltd)',
#   'Commissions': '$1,825.46'},
#  {'RANK': '8',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Sítio Portella',
#   'FARMER': 'Edir José de Carvalho',
#   'REGION': 'Sul de Minas',
#   'SCORE': '88.88',
#   'VARIETY': 'Yellow Catucaí',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Jorge Meneses de Assis',
#   'COMPANY': 'Monte Alegre Farm',
#   'COUNTRY': 'Brazil',
#   'Rank': '8',
#   'Farm': 'Sítio Portella',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$8.50/lb',
#   'Total Value': '$6,746.28',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$1,111.15'},
#  {'RANK': '9',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Santo Antônio',
#   'FARMER': 'Raimundo Dimas Santana Filho',
#   'REGION': 'Matas de Minas',
#   'SCORE': '88.80',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Kentaro Maruyama',
#   'COMPANY': 'Maruyama Coffee Co., Ltd.',
#   'COUNTRY': 'Japan',
#   'Rank': '9',
#   'Farm': 'Fazenda Santo Antônio',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$7.10/lb',
#   'Total Value': '$5,635.13',
#   'Company Name': 'cafe DAZAC, Eungubiro Roasters, Crema Costa',
#   'Commissions': '$888.92'},
#  {'RANK': '10',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Aterradinho',
#   'FARMER': 'Lilian Carrijo',
#   'REGION': 'Sul de Minas',
#   'SCORE': '88.61',
#   'VARIETY': 'Catucaí 2SL',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Naomi Nakahira',
#   'COMPANY': 'UCC Ueshima Coffee Co., Ltd.',
#   'COUNTRY': 'Japan',
#   'Rank': '10',
#   'Farm': 'Fazenda Aterradinho',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$8.10/lb',
#   'Total Value': '$6,428.81',
#   'Company Name': 'Dabov Specialty Coffee &\xa0Ascension Coffee Roasters',
#   'Commissions': '$1,047.66'},
#  {'RANK': '11',
#   'WEIGHT (kg)': '420',
#   'FARM': 'Fazenda Volta da Serra',
#   'FARMER': 'Agnaldo Martins de Assunção',
#   'REGION': 'Chapada Diamantina',
#   'SCORE': '88.50',
#   'VARIETY': 'Red Catuaí',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Nolan Hirte',
#   'COMPANY': 'Proud Mary Coffee',
#   'COUNTRY': 'United States (US)',
#   'Rank': '11',
#   'Farm': 'Fazenda Volta da Serra',
#   'Weight (lbs.)': '925.96',
#   'High Bid': '$8.90/lb',
#   'Total Value': '$8,241.04',
#   'Company Name': 'BEANBROTHERS',
#   'Commissions': '$1,370.42'},
#  {'RANK': '12',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Ecoagrícola Café Ltda',
#   'FARMER': 'Ecoagrícola Café Ltda',
#   'REGION': 'Chapada de Minas',
#   'SCORE': '88.46',
#   'VARIETY': 'Catucaí 2SL',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Philippe Barreca',
#   'COMPANY': 'Philippe Barreca AB.',
#   'COUNTRY': 'Sweden',
#   'Rank': '12',
#   'Farm': 'Ecoagrícola Café Ltda',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$16.00/lb',
#   'Total Value': '$12,698.88',
#   'Company Name': 'Sarutahiko Coffee Inc.',
#   'Commissions': '$2,539.78'},
#  {'RANK': '13',
#   'WEIGHT (kg)': '330',
#   'FARM': 'Sítio Lagoa II',
#   'FARMER': 'José Wanderley Viana',
#   'REGION': 'Mantiqueira de Minas',
#   'SCORE': '88.36',
#   'VARIETY': 'Yellow Catucaí',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Russell Hayward',
#   'COMPANY': 'Ascension Coffee Roasters',
#   'COUNTRY': 'United States (US)',
#   'Rank': '13',
#   'Farm': 'Sítio Lagoa II',
#   'Weight (lbs.)': '727.54',
#   'High Bid': '$7.00/lb',
#   'Total Value': '$5,092.78',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$800.29'},
#  {'RANK': '14',
#   'WEIGHT (kg)': '330',
#   'FARM': 'Sítio dos Colis',
#   'FARMER': 'Adila Pereira Coli',
#   'REGION': 'Mantiqueira de Minas',
#   'SCORE': '88.29',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Shinji Sekine',
#   'COMPANY': 'Wataru & Co., Ltd.',
#   'COUNTRY': 'Japan',
#   'Rank': '14',
#   'Farm': 'Sítio dos Colis',
#   'Weight (lbs.)': '727.54',
#   'High Bid': '$7.00/lb',
#   'Total Value': '$5,092.78',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$800.29'},
#  {'RANK': '15',
#   'WEIGHT (kg)': '330',
#   'FARM': 'Fazenda Mantissa',
#   'FARMER': 'Mauro Billi',
#   'REGION': 'Sul de Minas',
#   'SCORE': '88.14',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Silvio Leite',
#   'COMPANY': 'Agricafe',
#   'COUNTRY': 'Brazil',
#   'Rank': '15',
#   'Farm': 'Fazenda Mantissa',
#   'Weight (lbs.)': '727.54',
#   'High Bid': '$9.10/lb',
#   'Total Value': '$6,620.61',
#   'Company Name': 'Mercanta Ltd',
#   'Commissions': '$1,105.86'},
#  {'RANK': '16',
#   'WEIGHT (kg)': '420',
#   'FARM': 'Fazenda Sertãozinho',
#   'FARMER': 'Fazenda Sertãozinho',
#   'REGION': 'Sul de Minas',
#   'SCORE': '88.04',
#   'VARIETY': 'Arara',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Soren Sylvest',
#   'COMPANY': 'COOP Danmark',
#   'COUNTRY': 'Denmark',
#   'Rank': '16',
#   'Farm': 'Fazenda Sertãozinho',
#   'Weight (lbs.)': '925.96',
#   'High Bid': '$10.60/lb',
#   'Total Value': '$9,815.18',
#   'Company Name': 'Ecom Japan Limited',
#   'Commissions': '$1,713.03'},
#  {'RANK': '17',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Paraíso',
#   'FARMER': 'Jorge Barakat',
#   'REGION': 'Cerrado Mineiro',
#   'SCORE': '88.02',
#   'VARIETY': 'Catuaí 144',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Stephen l hurst',
#   'COMPANY': 'Mercanta Ltd',
#   'COUNTRY': 'United Kingdom (UK)',
#   'Rank': '17',
#   'Farm': 'Fazenda Paraíso',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$11.90/lb',
#   'Total Value': '$9,444.79',
#   'Company Name': 'TAKAMURA COFFEE ROASTERS',
#   'Commissions': '$1,726.25'},
#  {'RANK': '18',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Dona Neném',
#   'FARMER': 'Eduardo Pinheiro Campos',
#   'REGION': 'Cerrado Mineiro',
#   'SCORE': '87.80',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Suzuki Taroh',
#   'COMPANY': 'Saza Coffee',
#   'COUNTRY': 'Japan',
#   'Rank': '18',
#   'Farm': 'Fazenda Dona Neném',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$8.40/lb',
#   'Total Value': '$6,666.91',
#   'Company Name': 'Kaffebrenneriet As',
#   'Commissions': '$1,095.28'},
#  {'RANK': '19',
#   'WEIGHT (kg)': '480',
#   'FARM': 'Fazenda Zaroca',
#   'FARMER': 'Gilberto Augusto Cainelli Basilio',
#   'REGION': 'Sul de Minas',
#   'SCORE': '87.69',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Thomas Pulpan',
#   'COMPANY': 'Kaffebrenneriet as',
#   'COUNTRY': 'Norway',
#   'Rank': '19',
#   'Farm': 'Fazenda Zaroca',
#   'Weight (lbs.)': '1058.24',
#   'High Bid': '$9.00/lb',
#   'Total Value': '$9,524.16',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$1,587.36'},
#  {'RANK': '20',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Fortaleza',
#   'FARMER': 'Alessandro Alves Hervaz',
#   'REGION': 'Mantiqueira de Minas',
#   'SCORE': '87.68',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Valentina Moksunova',
#   'COMPANY': 'Hummingbird Coffee LLC',
#   'COUNTRY': 'Russia',
#   'Rank': '20',
#   'Farm': 'Fazenda Fortaleza',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$10.10/lb',
#   'Total Value': '$8,016.17',
#   'Company Name': 'TOA COFFEE Co.,Ltd.',
#   'Commissions': '$1,369.10'},
#  {'RANK': '21',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Camocim',
#   'FARMER': 'Henrique Leivas Sloper de Araújo',
#   'REGION': 'Montanhas do Espírito Santo',
#   'SCORE': '87.68',
#   'VARIETY': 'Catucaí Açu-Iapar 59',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Yasuhide Izaki',
#   'COMPANY': 'HoneyCoffee (Izaki Coffee Co. Ltd)',
#   'COUNTRY': 'Japan',
#   'Rank': '21',
#   'Farm': 'Fazenda Camocim',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$8.00/lb',
#   'Total Value': '$6,349.44',
#   'Company Name': 'Kyokuto Fadie Corporation',
#   'Commissions': '$1,031.78'},
#  {'RANK': '22',
#   'WEIGHT (kg)': '450',
#   'FARM': 'Sítio Santa Terezinha',
#   'FARMER': 'Edson Rosa Garcia',
#   'REGION': 'Mantiqueira de Minas',
#   'SCORE': '87.54',
#   'VARIETY': 'Acaiá',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Yosuke Nagata',
#   'COMPANY': 'Hisashi Yamamoto Coffee INC. (Unir)',
#   'COUNTRY': 'Japan',
#   'Rank': '22',
#   'Farm': 'Sítio Santa Terezinha',
#   'Weight (lbs.)': '992.10',
#   'High Bid': '$7.70/lb',
#   'Total Value': '$7,639.17',
#   'Company Name': 'Honu Kato Coffee Inc.',
#   'Commissions': '$1,230.20'},
#  {'RANK': '23',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Barreiro',
#   'FARMER': 'Francisco Otávio Lotufo',
#   'REGION': 'Sul de Minas',
#   'SCORE': '87.52',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Yuko Itoi',
#   'COMPANY': 'Timesclub',
#   'COUNTRY': 'Japan',
#   'Rank': '23',
#   'Farm': 'Fazenda Barreiro',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$7.10/lb',
#   'Total Value': '$5,635.13',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$888.92'},
#  {'RANK': '24',
#   'WEIGHT (kg)': '330',
#   'FARM': 'Sítio Fortaleza',
#   'FARMER': 'Júlio Cesar Ferreira',
#   'REGION': 'Mantiqueira de Minas',
#   'SCORE': '87.48',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Natural',
#   'ROLE': 'International Jury Position',
#   'NAME': 'Yunson Lee',
#   'COMPANY': 'Terarosa',
#   'COUNTRY': 'South Korea',
#   'Rank': '24',
#   'Farm': 'Sítio Fortaleza',
#   'Weight (lbs.)': '727.54',
#   'High Bid': '$8.00/lb',
#   'Total Value': '$5,820.32',
#   'Company Name': 'cosmetocafe',
#   'Commissions': '$945.80'},
#  {'RANK': '25',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Sítio dos Estouros',
#   'FARMER': 'José Mauro Miranda',
#   'REGION': 'Matas de Minas',
#   'SCORE': '87.43',
#   'VARIETY': 'Catuaí 44',
#   'PROCESS': 'Pulped Natural',
#   'ROLE': nan,
#   'NAME': nan,
#   'COMPANY': nan,
#   'COUNTRY': nan,
#   'Rank': '25',
#   'Farm': 'Sítio dos Estouros',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$7.10/lb',
#   'Total Value': '$5,635.13',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$888.92'},
#  {'RANK': '26',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Fazenda Santa Mônica',
#   'FARMER': 'Jean Vilhena Faleiros',
#   'REGION': 'Sul de Minas',
#   'SCORE': '87.34',
#   'VARIETY': 'Yellow Bourbon',
#   'PROCESS': 'Natural',
#   'ROLE': nan,
#   'NAME': nan,
#   'COMPANY': nan,
#   'COUNTRY': nan,
#   'Rank': '26',
#   'Farm': 'Fazenda Santa Mônica',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$8.70/lb',
#   'Total Value': '$6,905.02',
#   'Company Name': 'Mercanta The Coffee Hunters, Alchemist Singapore, Artisan Roast Scotland, Dark Woods Coffee England, Micro Coffee Roasters China',
#   'Commissions': '$1,142.90'},
#  {'RANK': '27',
#   'WEIGHT (kg)': '360',
#   'FARM': 'Nascentes da Grama',
#   'FARMER': 'Clayton Mapelli Cerri',
#   'REGION': 'Média Mogiana',
#   'SCORE': '87.16',
#   'VARIETY': 'Obatã',
#   'PROCESS': 'Natural',
#   'ROLE': nan,
#   'NAME': nan,
#   'COMPANY': nan,
#   'COUNTRY': nan,
#   'Rank': '27',
#   'Farm': 'Nascentes da Grama',
#   'Weight (lbs.)': '793.68',
#   'High Bid': '$7.00/lb',
#   'Total Value': '$5,555.76',
#   'Company Name': 'Wataru & Co., Ltd.',
#   'Commissions': '$873.05'},
#  {'RANK': nan,
#   'WEIGHT (kg)': nan,
#   'FARM': nan,
#   'FARMER': nan,
#   'REGION': nan,
#   'SCORE': nan,
#   'VARIETY': nan,
#   'PROCESS': nan,
#   'ROLE': nan,
#   'NAME': nan,
#   'COMPANY': nan,
#   'COUNTRY': nan,
#   'Rank': 'Totals',
#   'Farm': nan,
#   'Weight (lbs.)': '22024.62',
#   'High Bid': '$11.80/lb',
#   'Total Value': '$259,870.67',
#   'Company Name': nan,
#   'Commissions': '$48,789.16'}]

# %%
import pandas as pd
url = requests.get('https://cupofexcellence.org/directory/90-4/')
table = pd.read_html(url.content)#多重リスト
data = {}
data.update(zip(table[-1][0], table[-1][1]))
data
# Out:
# {'Rank': '1b',
#  'Farm Name': 'Esperanza',
#  'Farmer/Rep.': 'Hilda Leguia Gonzales',
#  'Score': '90',
#  'Altitude': '1848',
#  'Year': '2020',
#  'City': 'La Convencion',
#  'Region': 'Cusco',
#  'Program': 'Perú 2020',
#  'Auction': 'Cup of Excellence',
#  'Overall': 'Complex, Creamy, Floral, High acidity, Lingering, Peach jam, Round, Silky, Thickness',
#  'Aroma/Flavor': 'Floral (7), Grape (3), Honey (3), Juicy (3), Chocolate (2), Creamy (2), Jasmine (2), Lemon & Lime (2), Lime (2), Mango (2), Melon (2), Milk Chocolate (2), Muscat (2), Orange (2), Strawberry (2), Apple, Apricot, Black Cherry, Black Currant, Black Tea, Blackberry, Butter, Citrus, Cocoa, Cream, Fruity, Grassy, Hibiscus, Jammy, Lemongrass, Liquorice, Lychee, Mandarin Orange, Molasses, Peach, Pear, Pomelo, Powdery, Red Currant, Roasted Hazelnut, Rose Hips, Salted lemon, Savory, Stone Fruit, Sweet & Sugary, Tomato, Tropical Fruit, WatermelonCitric Acid (4), Tartaric Acid (2), Bright, Complex, Lively, Malic Acid, Pungent, Refine, Sweet, Tart, Tartaric acid, Vibrant',
#  'Acidity': 'Citric Acid (4), Tartaric Acid (2), Bright, Complex, Lively, Malic Acid, Pungent, Refine, Sweet, Tart, Tartaric acid, Vibrant',
#  'Processing system': 'Washed',
#  'Variety': '50% Gesha / 50% SL-09',
#  'Farm Size': '.73 ha'}
